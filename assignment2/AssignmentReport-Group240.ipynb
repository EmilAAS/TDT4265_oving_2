# %% [markdown]
# # Assignment 240 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)

# %% [markdown]
# ![task1a.png](attachment:task1a.png)

# %% [markdown]
# ## task 1b)

# %% [markdown]
# ![task1b-2.png](attachment:task1b-2.png)

# %% [markdown]
# # Task 2
# Mean: 33.55, stddev: 78.88

# %% [markdown]
# ## Task 2c)
# ![task2c_train_loss.png](attachment:6317e580-5d88-4e39-999b-df7564c96dfb.png)

# %% [markdown]
# ## Task 2d)
# 785 * 64 + 64 * 10 = 50880 number of parameters
#
# .

# %% [markdown]
# # Task 3

# %% [markdown]
# ![Figure_2.png](attachment:b25bfefc-2b1b-4775-adac-2420732caf9a.png)

# %% [markdown]
# Adding improved weight intialization, with standard deviation based on the number of inputs, yielded the biggest leap in validation accuracy. It is worth to note the both task 2 model and improved weights model approximately ran through the same amount og training epochs. Even though not plotted in the report it was also seen that the gap between training an validation accuracy decreased for the improved weight initialization which indicated that the model more generalized and overfitted less.
#
# Implementing LeCuns improved sigmoid function in 3b improved the validation accuracy even further and the number of epochs decreased significantly. This is due to the fact that the average cross entropy loss function converged a lot faster, which in turn made the early stoppage function kick in much sooner.
#
# The final addition to the model was momentum gave a slight increase in performance, as number of epochs decreased. The validation accuracy did not improve from 3b. the final validation accuracy of the model was around 96%, and early stoppage kicked in after 14 epochs

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# Plots from task 4b illustrates the effects of changing the number of nodes in the hidden layer. We observe that a 32 nodes causes a significantly worse validation accuracy even though it performes a larger amount of training steps. 128 nodes improves the accuracy a bit from 64, but as a consequence the run time of the network is increased. averages cross entropy loss converges pretty similarly for 64 and 128 nodes, and therefore 64 nodes is a good compromise between performance and efficiency.

# %% [markdown]
# ## Task 4b)
# ![Figure_3.png](attachment:750b62e4-0e79-4fc3-af92-4d265a5757c5.png)

# %% [markdown]
# ## Task 4d)
# previous network was based on 1 hidden layer with 64 nodes: 785 * 64 + 64 * 10 = 50880 number of parameters
#
# New network with 2 hidden layers of 59 nodes: 785 * 60 + 60 * 60 + 60 * 10 = 51300 number of parameters.
#
# The result is plotted in task 4e along with 10 hidden layer network for comparison.
# The two different networks seemed to perform similarly, with equal average cross entropy loss and validation accuracy. 60 nodes for the 2 layer network as choosen in order to achieve similar number of parameters. Testing with 59 noes instead gave similar results.

# %% [markdown]
# ## Task 4e)
# ![Figure_4.png](attachment:2770261f-cea7-41f7-bc93-19c333408544.png)

# %% [markdown]
# Implementation of a 10 hidden layer network with 64 nodes in each layer gave worse performance than the baseline network with 1 hidden layer. The validation accuracy decreased and the average cross entropy loss had a big variance and converged slowly. This may be simply due to the fact that the model simply is too complex for the problem. Too many weights makes it harder to initialize the correct hyper parameters, and backpropagation can become more challenging as it tends to increase or decrease the weight values greatly with more hidden layer.
